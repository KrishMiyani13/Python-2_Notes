# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {'DepartMent':['IT','IT','HR','FINANCE','HR','IT'],
         'Enployee':['A','B','C','D','E','F'],
         'Salary':[55000,60000,65000,45000,60000,55000],
         'Experince':[2,4,3,1,4,5]}

df = pd.DataFrame(data)
df
# Out:
#   DepartMent Enployee  Salary  Experince
# 0         IT        A   55000          2
# 1         IT        B   60000          4
# 2         HR        C   65000          3
# 3    FINANCE        D   45000          1
# 4         HR        E   60000          4
# 5         IT        F   55000          5

# %%
df.groupby(['Salary','Experince']).sum()
# Out:
#                  DepartMent Enployee
# Salary Experince
# 45000  1            FINANCE        D
# 55000  2                 IT        A
#        5                 IT        F
# 60000  4               ITHR       BE
# 65000  3                 HR        C

# %%
df.groupby('DepartMent')['Salary'].sum()
# Out:
# DepartMent
# FINANCE     45000
# HR         125000
# IT         170000
# Name: Salary, dtype: int64

# %%
df.groupby('DepartMent')['Experince'].mean()
# Out:
# DepartMent
# FINANCE    1.000000
# HR         3.500000
# IT         3.666667
# Name: Experince, dtype: float64

# %%
df.groupby('DepartMent').agg({'Salary':['mean','max'],'Experince':['sum','mean']})
# Out:
#                   Salary        Experince
#                     mean    max       sum      mean
# DepartMent
# FINANCE     45000.000000  45000         1  1.000000
# HR          62500.000000  65000         7  3.500000
# IT          56666.666667  60000        11  3.666667

# %%
df.groupby('DepartMent')['Salary'].apply(lambda x:x.max()-x.min())
# Out:
# DepartMent
# FINANCE       0
# HR         5000
# IT         5000
# Name: Salary, dtype: int64

# %%
grouped = df.groupby('DepartMent')
grouped.get_group('IT')
# Out:
#   DepartMent Enployee  Salary  Experince
# 0         IT        A   55000          2
# 1         IT        B   60000          4
# 5         IT        F   55000          5

# %%
df.groupby('DepartMent').nth(0)
# Out:
#   DepartMent Enployee  Salary  Experince
# 0         IT        A   55000          2
# 2         HR        C   65000          3
# 3    FINANCE        D   45000          1

# %%
df.groupby('DepartMent').groups
# Out:
# {'FINANCE': [3], 'HR': [2, 4], 'IT': [0, 1, 5]}

# %%
data1 = pd.read_csv('PANDAS_DATA/imdb-top-1000.csv')
df1 = pd.DataFrame(data1)

# %%
df1.count()
# Out:
# Series_Title     1000
# Released_Year    1000
# Runtime          1000
# Genre            1000
# IMDB_Rating      1000
# Director         1000
# Star1            1000
# No_of_Votes      1000
# Gross            1000
# Metascore         843
# dtype: int64

# %%
df1['Genre'].nunique()
# Out:
# 14

# %%
genre = df1.groupby('Genre')
genre.sum()
genre.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
genre['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
df1['Genre'].unique()
# Out:
# array(['Drama', 'Crime', 'Action', 'Biography', 'Western', 'Comedy',
#        'Adventure', 'Animation', 'Horror', 'Mystery', 'Film-Noir',
#        'Fantasy', 'Family', 'Thriller'], dtype=object)

# %%
genre['IMDB_Rating'].mean().sort_values(ascending=False).head(1)
# Out:
# Genre
# Western    8.35
# Name: IMDB_Rating, dtype: float64

# %%
df1.groupby('Director')['No_of_Votes'].sum().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan    11578345
# Quentin Tarantino     8123208
# Steven Spielberg      7817166
# David Fincher         6607859
# Martin Scorsese       6513530
#                        ...
# J. Lee Thompson         26457
# Peter Mullan            25938
# René Laloux             25229
# Francis Lee             25198
# Kaige Chen              25088
# Name: No_of_Votes, Length: 548, dtype: int64

# %%
genre['IMDB_Rating'].max().sort_values(ascending=False)
# Out:
# Genre
# Drama        9.3
# Crime        9.2
# Action       9.0
# Biography    8.9
# Western      8.8
# Adventure    8.6
# Comedy       8.6
# Animation    8.6
# Horror       8.5
# Mystery      8.4
# Fantasy      8.1
# Film-Noir    8.1
# Family       7.8
# Thriller     7.8
# Name: IMDB_Rating, dtype: float64

# %%
df1.groupby("Star1")['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks               12
# Robert De Niro          11
# Clint Eastwood          10
# Al Pacino               10
# Humphrey Bogart          9
#                         ..
# Zbigniew Zamachowski     1
# Zooey Deschanel          1
# Çetin Tekindor           1
# Éric Toledano            1
# Aaron Taylor-Johnson     1
# Name: Series_Title, Length: 660, dtype: int64

# %%
genre.size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
len(genre)
# Out:
# 14

# %%
genre.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
genre.count()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172            172      172          172       172    172
# Adventure            72             72       72           72        72     72
# Animation            82             82       82           82        82     82
# Biography            88             88       88           88        88     88
# Comedy              155            155      155          155       155    155
# Crime               107            107      107          107       107    107
# Drama               289            289      289          289       289    289
# Family                2              2        2            2         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       11           11        11     11
# ...

# %%
genre.nth([0,1,10])
# Out:
#                                       Series_Title Released_Year  Runtime  \
# 0                         The Shawshank Redemption          1994      142
# 1                                    The Godfather          1972      175
# 2                                  The Dark Knight          2008      152
# 3                           The Godfather: Part II          1974      202
# 5    The Lord of the Rings: The Return of the King          2003      201
# 7                                 Schindler's List          1993      195
# 9                                       Fight Club          1999      139
# 12                 Il buono, il brutto, il cattivo          1966      161
# 15                                      Goodfellas          1990      146
# 19                                    Gisaengchung          2019      132
# 21                                    Interstellar          2014      169
# 23                   Sen to Chihiro no kamikakushi          2001      125
# ...

# %%
genre.agg({'Runtime':'mean','IMDB_Rating':'mean','Gross':'sum'})
# Out:
#               Runtime  IMDB_Rating         Gross
# Genre
# Action     129.046512     7.949419  3.263226e+10
# Adventure  134.111111     7.937500  9.496922e+09
# Animation   99.585366     7.930488  1.463147e+10
# Biography  136.022727     7.938636  8.276358e+09
# Comedy     112.129032     7.901290  1.566387e+10
# Crime      126.392523     8.016822  8.452632e+09
# Drama      124.737024     7.957439  3.540997e+10
# Family     107.500000     7.800000  4.391106e+08
# Fantasy     85.000000     8.000000  7.827267e+08
# Film-Noir  104.000000     7.966667  1.259105e+08
# Horror     102.090909     7.909091  1.034649e+09
# Mystery    119.083333     7.975000  1.256417e+09
# Thriller   108.000000     7.800000  1.755074e+07
# Western    148.250000     8.350000  5.822151e+07

# %%
df.groupby('DepartMent').agg({'Salary':['mean','max'],'Experince':['sum','mean']})
# Out:
#                   Salary        Experince
#                     mean    max       sum      mean
# DepartMent
# FINANCE     45000.000000  45000         1  1.000000
# HR          62500.000000  65000         7  3.500000
# IT          56666.666667  60000        11  3.666667

# %%
genre['IMDB_Rating'].agg(lambda x:x.max()-x.min())
# Out:
# Genre
# Action       1.4
# Adventure    1.0
# Animation    1.0
# Biography    1.3
# Comedy       1.0
# Crime        1.6
# Drama        1.7
# Family       0.0
# Fantasy      0.2
# Film-Noir    0.3
# Horror       0.9
# Mystery      0.8
# Thriller     0.0
# Western      1.0
# Name: IMDB_Rating, dtype: float64
