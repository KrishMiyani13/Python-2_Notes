# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'name':['A','B','C','D','E'],
                   'Department':['CS','IT','EC','CS','IT']})
df
# Out:
#   name Department
# 0    A         CS
# 1    B         IT
# 2    C         EC
# 3    D         CS
# 4    E         IT

# %%
df_encode = pd.get_dummies(df,columns=['Department'])
df_encode
# Out:
#   name  Department_CS  Department_EC  Department_IT
# 0    A           True          False          False
# 1    B          False          False           True
# 2    C          False           True          False
# 3    D           True          False          False
# 4    E          False          False           True

# %%
df_encode = pd.get_dummies(df,columns=['Department'],drop_first=True)
df_encode
# Out:
#   name  Department_EC  Department_IT
# 0    A          False          False
# 1    B          False           True
# 2    C           True          False
# 3    D          False          False
# 4    E          False           True

# %%
df_encode = pd.get_dummies(df,columns=['Department'],drop_first=False)
df_encode
# Out:
#   name  Department_CS  Department_EC  Department_IT
# 0    A           True          False          False
# 1    B          False          False           True
# 2    C          False           True          False
# 3    D           True          False          False
# 4    E          False          False           True

# %%
df = pd.DataFrame({'name':['A','B','C','D','E'],
                   'Department':['CS','IT','EC','CS','IT'],
                   'score':[60,45,78,90,34]})
df
# Out:
#   name Department  score
# 0    A         CS     60
# 1    B         IT     45
# 2    C         EC     78
# 3    D         CS     90
# 4    E         IT     34

# %%
df['Gender'] = np.where(df['score']>60,"A",'B')
df
# Out:
#   name Department  score Gender
# 0    A         CS     60      B
# 1    B         IT     45      B
# 2    C         EC     78      A
# 3    D         CS     90      A
# 4    E         IT     34      B

# %%
df['Gender'] = np.where(df['score']>60,"A",np.where(df['score']>40,'B','C'))
df
# Out:
#   name Department  score Gender
# 0    A         CS     60      B
# 1    B         IT     45      B
# 2    C         EC     78      A
# 3    D         CS     90      A
# 4    E         IT     34      C

# %%
from  sklearn.model_selection import train_test_split
df = pd.DataFrame({
    'Hours':[1,2,3,4,5],
    'score':[10,45,34,67,80]
})

x = df[['Hours']]
y= df[['score']]

x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.8)
print(x_train)
print(x_test)
# Out:
#    Hours
# 1      2
# 3      4
# 4      5
# 0      1
#    Hours
# 2      3
